# %%
SOURCE_PATH = "/Volumes/workspace/default/spooky_authors_dataset/train_part*.csv"  # Path to your CSV files
BRONZE_TABLE = "bronze_spooky_authors"

# %%
# import libraries
from pyspark.sql.functions import current_timestamp, col, lit
from pyspark.sql.types import StringType

# %%
# Read all CSV files from source
# Using _metadata.file_path for Unity Catalog compatibility
df_bronze = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load(SOURCE_PATH)
)

# %%
# Add metadata columns
df_bronze = (
    df_bronze
    .withColumn("_ingestion_timestamp", current_timestamp())
    .withColumn("_layer", lit("bronze"))
)

# %%
# Display sample data
print("Sample raw data:")
df_bronze.show(5, truncate=False)
# Out:
# Sample raw data:
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+
# |id     |text                                                                                                                                                                                                                                                                         |author|_ingestion_timestamp      |_layer|
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+
# |id12369|This spot, dedicated to sweetest recollections, the deserted house and neglected garden were well adapted to nurse my melancholy.                                                                                                                                            |MWS   |2026-01-03 23:08:18.037973|bronze|
# |id02893|As for one lady, she obeyed Monsieur Maillard to the letter, and thrusting out her tongue, which was an excessively long one, held it very resignedly, with both hands, until the end of the entertainment.                                                                  |EAP   |2026-01-03 23:08:18.037973|bronze|
# |id23856|The slope of the sides of the vast funnel became momently less and less steep.                                                                                                                                                                                               |EAP   |2026-01-03 23:08:18.037973|bronze|
# |id17261|Fear was upon the whole pitiful crowd, for they did not know what the law would exact of them if the affair were not hushed up; and they were grateful when West, in spite of my involuntary shudders, offered to get rid of the thing quietly for a purpose I knew too well.|HPL   |2026-01-03 23:08:18.037973|bronze|
# |id20479|The fury of the tempest immediately died away, and a dead calm sullenly succeeded.                                                                                                                                                                                           |EAP   |2026-01-03 23:08:18.037973|bronze|
# +-------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+
# only showing top 5 rows

# %%
# Show schema
print("Schema:")
df_bronze.printSchema()
# Out:
# Schema:
# root
#  |-- id: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = false)
#  |-- _layer: string (nullable = false)

# %%
# Record count
record_count = df_bronze.count()
print(f"\nTotal records to ingest: {record_count:,}")
# Out:
# Total records to ingest: 19,579

# %%
# Check for nulls in key columns
print("\nNull counts per column:")
for col_name in df_bronze.columns:
    null_count = df_bronze.filter(col(col_name).isNull()).count()
    print(f"  {col_name}: {null_count:,} nulls")
# Out:
# Null counts per column:
#   id: 0 nulls
#   text: 0 nulls
#   author: 0 nulls
#   _ingestion_timestamp: 0 nulls
#   _layer: 0 nulls

# %%
# Write to Delta table
(
    df_bronze
    .write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(BRONZE_TABLE)
)

print(f"✓ Bronze table '{BRONZE_TABLE}' created successfully!")
# Out:
# ✓ Bronze table 'bronze_spooky_authors' created successfully!

# %%
# Verify the table was created
bronze_count = spark.table(BRONZE_TABLE).count()
print(f"✓ Bronze table contains {bronze_count:,} records")
# Out:
# ✓ Bronze table contains 19,579 records

# %%
# Show sample from table
print("\nSample from Bronze table:")
spark.sql(f"SELECT * FROM {BRONZE_TABLE} LIMIT 5").show(truncate=False)
# Out:
# Sample from Bronze table:
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+
# |id     |text                                                                                                                                                                                                                                   |author|_ingestion_timestamp      |_layer|
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+
# |id26305|This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.|EAP   |2026-01-03 23:09:39.969833|bronze|
# |id17569|It never once occurred to me that the fumbling might be a mere mistake.                                                                                                                                                                |HPL   |2026-01-03 23:09:39.969833|bronze|
# |id11008|In his left hand was a gold snuff box, from which, as he capered down the hill, cutting all manner of fantastic steps, he took snuff incessantly with an air of the greatest possible self satisfaction.                               |EAP   |2026-01-03 23:09:39.969833|bronze|
# |id27763|How lovely is spring As we looked from Windsor Terrace on the sixteen fertile counties spread beneath, speckled by happy cottages and wealthier towns, all looked as in former years, heart cheering and fair.                         |MWS   |2026-01-03 23:09:39.969833|bronze|
# |id12958|Finding nothing else, not even gold, the Superintendent abandoned his attempts; but a perplexed look occasionally steals over his countenance as he sits thinking at his desk.                                                         |HPL   |2026-01-03 23:09:39.969833|bronze|
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------+------+

# %%
# Return success for job orchestration
dbutils.notebook.exit(f"SUCCESS: Bronze layer created with {bronze_count} records")
